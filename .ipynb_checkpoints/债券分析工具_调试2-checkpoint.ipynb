# %%
import sys
# sys.path.insert(0, '/home/gfzg/workspace/数据下载/Wind/Packages')
# sys.path.insert(0, '/home/gfzg/workspace/债券分析/Packages')
import os
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import warnings
from importlib import reload
import re
from datetime import datetime, timedelta
warnings.filterwarnings("ignore")
from tqdm.notebook import tqdm
import math
import copy
import matplotlib.pyplot as plt
import seaborn as sns
import janitor   
# 需要找到C:\Users\lenovo\anaconda3\Lib\site-packages路径下的janitor.py 
# 把ConfigParser改成configparse
# from werkzeug.contrib.fixers import ProxyFix 改成 from werkzeug.middleware.proxy_fix import ProxyFix
import time
from progressbar import progressbar as pbar # 该用pg进度条了
from tabulate import tabulate
# 核心包
# import Wind
import Bonder
import Selector
import dolphindb as ddb

import matplotlib as mpl
plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题

# %% [markdown]
# ### 字段说明

# %% [markdown]
# ### 筛选方式说明

# %%
# 筛选最外层由[]包裹, 内部元素由 and 连接：
# 元素可以是以下两种：

#  1. (字段,逻辑符,值): 
# 逻辑符 支持 "==","!=",">=","<=",">","<","isin","isna","isnotna"
# 当逻辑符是isin时 值为 []
# 当逻辑符时isna或isnotna时 值可任意输入 一般输入''

# 2. [(字段,逻辑符,值),...,(字段,逻辑符,值)]: 
# 内部(字段,逻辑符,值)间由 or 连接

# BondStaticFilters = [
#     ('isPerpetualBonds','==',0),
#     [('CNBD_HIDDEN_CREDITRATING','==','AAA'),('CNBD_HIDDEN_CREDITRATING','==','AA+')],
# ]
# BondStaticFilters = [
#     ('isPerpetualBonds','==',0),
#     ('CNBD_HIDDEN_CREDITRATING','isin',['AAA','AA+']),
# ]
# 如BondStaticFilters表达为 不是永续债 且 （债券等级AAA 或 债券等级AA+）的债券

# %%
reload(Bonder)    # 重新载入之前载入的模块
# 初始化债券分析框架 Bonder
BondAnalyzer = Bonder.BondAnalyzer()

# 导入3张表
# STATIC
# BONDS
# FILLED_GUOKAI 见最上方国开债部分

# 静态筛选 
BondStaticFilters = [
    ('suffix','isin',['IB','SH','SZ']), # 默认选择标准代码
    ('CATEGORY1','==','信用债'),  # 默认选择信用债，不含利率债、同业存单、ABS、可转债
    ('isPerpetualBonds','==',0),  # 剔除：永续债
    ('IS_FAILURE','==',0)        # 剔除：发行失败
#     ('B_INFO_GUARTYPE','isna','') # 剔除：附带担保债
]
# 动态筛选
# 只考虑对应计算节点剩余期 限在 10 年以内个券
# 0. 仅保留 IB SH SZ债券
BondDynamicFilters = [
    ('B_ANAL_MATU_CNBD','<=', 10)
]
# 生成债券池
dataConfig = {
    'StaticPath': './Results/STATIC.parquet',
    'BondsPath': './Results/BONDS.parquet', 
    'FilledGuokaiPath': './Results/FILLED_GUOKAI.parquet',
    'BondStaticFilters': BondStaticFilters,
    'BondDynamicFilters': BondDynamicFilters,
}
df = BondAnalyzer.dataCenter(dataConfig)
# Out:
# 数据筛选中...请等待
# 筛选结果数据量： 14039
# STATIC: suffix isin ['IB', 'SH', 'SZ'] and CATEGORY1 == 信用债 and isPerpetualBonds == 0 and IS_FAILURE == 0
# 数据筛选中...请等待
# 筛选结果数据量： 11014822
# BONDS: B_ANAL_MATU_CNBD <= 10
# 信用计算利差中
# 数据处理完成

# %%
STATIC = pd.read_parquet('./Results/STATIC.parquet')
STATIC.to_csv('./Results/STATIC.csv', encoding='gbk')
STATIC.drop('B_INFO_ISSUERCODE', inplace=True, axis=1)
STATIC
# Out:
#       S_INFO_WINDCODE                             B_INFO_FULLNAME  \
# 0           112212.SZ                     中山公用事业集团股份有限公司2014年公司债券
# 1           112123.SZ                中山公用事业集团股份有限公司2012年(第一期)公司债券
# 2           136468.SH                瑞茂通供应链管理股份有限公司2016年公司债券(第二期)
# 3           136250.SH                瑞茂通供应链管理股份有限公司2016年公司债券(第一期)
# 4           112837.SZ    深圳赛格股份有限公司2018年面向合格投资者公开发行公司债券(第一期)(品种二)
# ...               ...                                         ...
# 21925    061709002.IB           兴业皖新阅嘉一期房地产投资信托基金(REIT)资产支持证券优先B级
# 21926    061709001.IB           兴业皖新阅嘉一期房地产投资信托基金(REIT)资产支持证券优先A级
# 21927    j16030901.SH                      2014年恒泰证券股份有限公司债券(品种一)
# 21928       115036.SH  中邮证券有限责任公司2023年面向专业机构投资者公开发行公司债券(第一期)(品种二)
# 21929       150787.SH            中航证券有限公司2018年非公开发行次级债券(第二期)(品种一)
#
#         B_INFO_ISSUER B_INFO_CARRYDATE B_INFO_MATURITYDATE  B_INFO_TERM_YEAR_  \
# 0      中山公用事业集团股份有限公司         20140703            20170703             3.0000
# 1      中山公用事业集团股份有限公司         20121029            20191029             7.0000
# 2      瑞茂通供应链管理股份有限公司         20160613            20190613             3.0000
# 3      瑞茂通供应链管理股份有限公司         20160301            20190301             3.0000
# 4          深圳赛格股份有限公司         20181225            20200625             1.5014
# ...               ...              ...                 ...                ...
# 21925      兴业国际信托有限公司         20170220            20350220            18.0110
# 21926      兴业国际信托有限公司         20170220            20350220            18.0110
# 21927      恒泰证券股份有限公司                                                  3.0000
# 21928      中邮证券有限责任公司                                                  5.0000
# 21929        中航证券有限公司                                                  3.0000
#
#       B_INFO_PAYMENTTYPE S_INFO_EXCHMARKET B_INFO_INTERESTFREQUENCY  \
# 0                     单利              SZSE                      每1年
# 1                     单利              SZSE                      每1年
# 2                     单利               SSE                      每1年
# 3                     单利               SSE                      每1年
# 4                     单利              SZSE                      每9月
# ...                  ...               ...                      ...
# 21925                 单利               NIB                      每3月
# 21926                 单利               NIB                      每3月
# 21927                 单利               SSE                      每1年
# 21928                 单利               SSE                      每1年
# 21929                 单利               SSE                      每1年
#
#        IS_FAILURE  B_INFO_GUARTYPE  IS_CORPORATE_BOND B_INFO_ISSUERTYPE  \
# 0             0.0      507002000.0                1.0                企业
# 1             0.0      507002000.0                1.0                企业
# 2             0.0      507002000.0                1.0                企业
# 3             0.0      507002000.0                1.0                企业
# 4             0.0      507002000.0                1.0                企业
# ...           ...              ...                ...               ...
# 21925         0.0      507007000.0                0.0
# 21926         0.0      507007000.0                0.0
# 21927         1.0      507002000.0                0.0              证券公司
# 21928         1.0      507002000.0                0.0              证券公司
# 21929         1.0      507002000.0                0.0              证券公司
#
#       B_INFO_ISSUETYPE suffix S_INFO_INDUSTRYNAME_WindLevel1  \
# 0                   公募     SZ                            公司债
# 1                   公募     SZ                            公司债
# 2                   公募     SH                            公司债
# 3                   公募     SH                            公司债
# 4                   公募     SZ                            公司债
# ...                ...    ...                            ...
# 21925               公募     IB                         资产支持证券
# 21926               公募     IB                         资产支持证券
# 21927               公募     SH                            金融债
# 21928               公募     SH                            金融债
# 21929               私募     SH                            金融债
#
#       S_INFO_INDUSTRYNAME_WindLevel2 CATEGORY1 CATEGORY2  CATEGORY3  \
# 0                              一般公司债       信用债       公司债
# 1                              一般公司债       信用债       公司债
# 2                              一般公司债       信用债       公司债
# 3                              一般公司债       信用债       公司债
# 4                              一般公司债       信用债       公司债
# ...                              ...       ...       ...        ...
# 21925                      银保监会主管ABS       ABS       ABS  银保监会主管ABS
# 21926                      银保监会主管ABS       ABS       ABS  银保监会主管ABS
# 21927                                      信用债       金融债    其它金融机构债
# 21928                                      信用债       金融债    其它金融机构债
# 21929                                      信用债       金融债    其它金融机构债
#
#        isPerpetualBonds  isTier2CapitalBonds BOND_TYPE  \
# 0                     0                    0       产业债
# 1                     0                    0       产业债
# 2                     0                    0       产业债
# 3                     0                    0       产业债
# 4                     0                    0       产业债
# ...                 ...                  ...       ...
# 21925                 0                    0       产业债
# 21926                 0                    0       产业债
# 21927                 0                    0       金融债
# 21928                 0                    0       金融债
# 21929                 0                    0       金融债
#
#       B_AGENCY_GUARANTORNATURE S_INFO_COMPIND_NAME1 S_INFO_COMPIND_NAME2  \
# 0                       地方国有企业                 公用事业                公用事业Ⅱ
# 1                       地方国有企业                 公用事业                公用事业Ⅱ
# 2                         民营企业                   工业                   运输
# 3                         民营企业                   工业                   运输
# 4                       地方国有企业                  房地产                 房地产Ⅱ
# ...                        ...                  ...                  ...
# 21925                     None                 None                 None
# 21926                     None                 None                 None
# 21927                     公众企业                   金融                 多元金融
# 21928                   中央国有企业                   金融                 多元金融
# 21929                   中央国有企业                   金融                 多元金融
#
#       S_INFO_COMPIND_NAME3 S_INFO_COMPIND_NAME4 PROVINCE  CITY DISTRICT  AREA  \
# 0                      水务Ⅲ                   水务      广东省   中山市
# 1                      水务Ⅲ                   水务      广东省   中山市
# 2                 航空货运与物流Ⅲ              航空货运与物流     None  None     None  None
# 3                 航空货运与物流Ⅲ              航空货运与物流     None  None     None  None
# 4                 房地产管理和开发              房地产经营公司     None  None     None  None
# ...                    ...                  ...      ...   ...      ...   ...
# 21925                 None                 None     None  None     None  None
# 21926                 None                 None     None  None     None  None
# 21927                 资本市场            投资银行业与经纪业     None  None     None  None
# 21928                 资本市场            投资银行业与经纪业     None  None     None  None
# 21929                 资本市场            投资银行业与经纪业     None  None     None  None
#
#       ADMINISTRATIVE_LEVEL  IS_SUB
# 0                      地级市     1.0
# 1                      地级市     1.0
# 2                     None     NaN
# 3                     None     NaN
# 4                     None     NaN
# ...                    ...     ...
# 21925                 None     NaN
# 21926                 None     NaN
# 21927                 None     NaN
# 21928                 None     NaN
# 21929                 None     NaN
#
# [21930 rows x 34 columns]

# %%
BONDS = pd.read_parquet('./Results/BONDS.parquet')
BONDS.to_csv('./Results/BONDS.csv',encoding='gbk')
BONDS

# %%
FILLED_GUOKAI = pd.read_parquet('./Results/FILLED_GUOKAI.parquet')
FILLED_GUOKAI.to_csv('./Results/FILLED_GUOKAI.csv',encoding='gbk')
FILLED_GUOKAI
# Out:
#          B_ANAL_MATU_CNBD  TRADE_DT  B_ANAL_YIELD_GUOKAI
# 0                    0.00  20100104              2.29290
# 1                    0.01  20100104              2.56120
# 2                    0.02  20100104              2.82950
# 3                    0.03  20100104              2.93450
# 4                    0.04  20100104              3.03950
# ...                   ...       ...                  ...
# 1717924              4.96  20230915             10.88738
# 1717925              4.97  20230915             10.88951
# 1717926              4.98  20230915             10.89164
# 1717927              4.99  20230915             10.89377
# 1717928              5.00  20230915             10.89590
#
# [1717929 rows x 3 columns]

# %%
df
# Out:
#         S_INFO_WINDCODE          B_INFO_FULLNAME B_INFO_ISSUER  \
# 0             078036.IB            2007年上海城市建设债券  上海城投(集团)有限公司
# 1             078036.IB            2007年上海城市建设债券  上海城投(集团)有限公司
# 2             078036.IB            2007年上海城市建设债券  上海城投(集团)有限公司
# 3             078036.IB            2007年上海城市建设债券  上海城投(集团)有限公司
# 4             078036.IB            2007年上海城市建设债券  上海城投(集团)有限公司
# ...                 ...                      ...           ...
# 1050222      2223004.IB  国联人寿保险股份有限公司2022年资本补充债券  国联人寿保险股份有限公司
# 1050223      2223004.IB  国联人寿保险股份有限公司2022年资本补充债券  国联人寿保险股份有限公司
# 1050224      2223004.IB  国联人寿保险股份有限公司2022年资本补充债券  国联人寿保险股份有限公司
# 1050225      2223004.IB  国联人寿保险股份有限公司2022年资本补充债券  国联人寿保险股份有限公司
# 1050226      2223004.IB  国联人寿保险股份有限公司2022年资本补充债券  国联人寿保险股份有限公司
#
#         B_INFO_CARRYDATE B_INFO_MATURITYDATE  B_INFO_TERM_YEAR_  \
# 0               20070731            20220731               15.0
# 1               20070731            20220731               15.0
# 2               20070731            20220731               15.0
# 3               20070731            20220731               15.0
# 4               20070731            20220731               15.0
# ...                  ...                 ...                ...
# 1050222         20220324            20320324               10.0
# 1050223         20220324            20320324               10.0
# 1050224         20220324            20320324               10.0
# 1050225         20220324            20320324               10.0
# 1050226         20220324            20320324               10.0
#
#         B_INFO_PAYMENTTYPE S_INFO_EXCHMARKET B_INFO_INTERESTFREQUENCY  \
# 0                       单利               NIB                      每1年
# 1                       单利               NIB                      每1年
# 2                       单利               NIB                      每1年
# 3                       单利               NIB                      每1年
# 4                       单利               NIB                      每1年
# ...                    ...               ...                      ...
# 1050222                 单利               NIB                      每1年
# 1050223                 单利               NIB                      每1年
# 1050224                 单利               NIB                      每1年
# 1050225                 单利               NIB                      每1年
# 1050226                 单利               NIB                      每1年
#
#          IS_FAILURE  B_INFO_GUARTYPE  IS_CORPORATE_BOND B_INFO_ISSUERTYPE  \
# 0               0.0      507002000.0                0.0                企业
# 1               0.0      507002000.0                0.0                企业
# 2               0.0      507002000.0                0.0                企业
# 3               0.0      507002000.0                0.0                企业
# 4               0.0      507002000.0                0.0                企业
# ...             ...              ...                ...               ...
# 1050222         0.0      507002000.0                0.0            其它金融机构
# 1050223         0.0      507002000.0                0.0            其它金融机构
# 1050224         0.0      507002000.0                0.0            其它金融机构
# 1050225         0.0      507002000.0                0.0            其它金融机构
# 1050226         0.0      507002000.0                0.0            其它金融机构
#
#         B_INFO_ISSUETYPE suffix S_INFO_INDUSTRYNAME_WindLevel1  \
# 0                     公募     IB                            企业债
# 1                     公募     IB                            企业债
# 2                     公募     IB                            企业债
# 3                     公募     IB                            企业债
# 4                     公募     IB                            企业债
# ...                  ...    ...                            ...
# 1050222               公募     IB                            金融债
# 1050223               公募     IB                            金融债
# 1050224               公募     IB                            金融债
# 1050225               公募     IB                            金融债
# 1050226               公募     IB                            金融债
#
#         S_INFO_INDUSTRYNAME_WindLevel2 CATEGORY1 CATEGORY2 CATEGORY3  \
# 0                                一般企业债       信用债       企业债
# 1                                一般企业债       信用债       企业债
# 2                                一般企业债       信用债       企业债
# 3                                一般企业债       信用债       企业债
# 4                                一般企业债       信用债       企业债
# ...                                ...       ...       ...       ...
# 1050222                          保险公司债       信用债       金融债     保险公司债
# 1050223                          保险公司债       信用债       金融债     保险公司债
# 1050224                          保险公司债       信用债       金融债     保险公司债
# 1050225                          保险公司债       信用债       金融债     保险公司债
# 1050226                          保险公司债       信用债       金融债     保险公司债
#
#          isPerpetualBonds  isTier2CapitalBonds BOND_TYPE  \
# 0                       0                    0       城投债
# 1                       0                    0       城投债
# 2                       0                    0       城投债
# 3                       0                    0       城投债
# 4                       0                    0       城投债
# ...                   ...                  ...       ...
# 1050222                 0                    0       金融债
# 1050223                 0                    0       金融债
# 1050224                 0                    0       金融债
# 1050225                 0                    0       金融债
# 1050226                 0                    0       金融债
#
#         B_AGENCY_GUARANTORNATURE S_INFO_COMPIND_NAME1 S_INFO_COMPIND_NAME2  \
# 0                         地方国有企业                 公用事业                公用事业Ⅱ
# 1                         地方国有企业                 公用事业                公用事业Ⅱ
# 2                         地方国有企业                 公用事业                公用事业Ⅱ
# 3                         地方国有企业                 公用事业                公用事业Ⅱ
# 4                         地方国有企业                 公用事业                公用事业Ⅱ
# ...                          ...                  ...                  ...
# 1050222                   地方国有企业                   金融                  保险Ⅱ
# 1050223                   地方国有企业                   金融                  保险Ⅱ
# 1050224                   地方国有企业                   金融                  保险Ⅱ
# 1050225                   地方国有企业                   金融                  保险Ⅱ
# 1050226                   地方国有企业                   金融                  保险Ⅱ
#
#         S_INFO_COMPIND_NAME3 S_INFO_COMPIND_NAME4 PROVINCE  CITY DISTRICT  \
# 0                        水务Ⅲ                   水务       上海   上海市
# 1                        水务Ⅲ                   水务       上海   上海市
# 2                        水务Ⅲ                   水务       上海   上海市
# 3                        水务Ⅲ                   水务       上海   上海市
# 4                        水务Ⅲ                   水务       上海   上海市
# ...                      ...                  ...      ...   ...      ...
# 1050222                  保险Ⅲ              人寿与健康保险     None  None     None
# 1050223                  保险Ⅲ              人寿与健康保险     None  None     None
# 1050224                  保险Ⅲ              人寿与健康保险     None  None     None
# 1050225                  保险Ⅲ              人寿与健康保险     None  None     None
# 1050226                  保险Ⅲ              人寿与健康保险     None  None     None
#
#          AREA ADMINISTRATIVE_LEVEL  IS_SUB  TRADE_DT  B_ANAL_MATU_CNBD  \
# 0                              直辖市     0.0  20220104              0.57
# 1                              直辖市     0.0  20220105              0.57
# 2                              直辖市     0.0  20220106              0.56
# 3                              直辖市     0.0  20220107              0.56
# 4                              直辖市     0.0  20220110              0.55
# ...       ...                  ...     ...       ...               ...
# 1050222  None                 None     NaN  20230915              3.52
# 1050223  None                 None     NaN  20230918              3.51
# 1050224  None                 None     NaN  20230919              3.51
# 1050225  None                 None     NaN  20230920              3.51
# 1050226  None                 None     NaN  20230921              3.51
#
#          B_ANAL_YIELD_CNBD  B_ANAL_RESIDUALPRI CNBD_HIDDEN_CREDITRATING  \
# 0                   2.6754               100.0                      AAA
# 1                   2.6571               100.0                      AAA
# 2                   2.6319               100.0                      AAA
# 3                   2.6493               100.0                      AAA
# 4                   2.6501               100.0                      AAA
# ...                    ...                 ...                      ...
# 1050222             3.8859               100.0                      AA-
# 1050223             3.8789               100.0                      AA-
# 1050224             3.8359               100.0                      AA-
# 1050225             3.8434               100.0                      AA-
# 1050226             3.7996               100.0                      AA-
#
#         B_INFO_CREDITRATING_BOND B_INFO_ISSUERCODE B_INFO_CREDITRATING_ISSUER  \
# 0                            AAA           2002227                        AAA
# 1                            AAA           2002227                        AAA
# 2                            AAA           2002227                        AAA
# 3                            AAA           2002227                        AAA
# 4                            AAA           2002227                        AAA
# ...                          ...               ...                        ...
# 1050222                      AAA        UL3DUXx02g                         AA
# 1050223                      AAA        UL3DUXx02g                         AA
# 1050224                      AAA        UL3DUXx02g                         AA
# 1050225                      AAA        UL3DUXx02g                         AA
# 1050226                      AAA        UL3DUXx02g                         AA
#
#          B_ANAL_MATU_CNBD_YEAR  B_ANAL_YIELD_GUOKAI  CREDIT_SPREAD
# 0                          1.0              9.87239       -7.19699
# 1                          1.0              9.86199       -7.20489
# 2                          1.0              9.84668       -7.21478
# 3                          1.0              9.84458       -7.19528
# 4                          1.0              9.84960       -7.19950
# ...                        ...                  ...            ...
# 1050222                    4.0             10.63222       -6.74632
# 1050223                    4.0                  NaN            NaN
# 1050224                    4.0                  NaN            NaN
# 1050225                    4.0                  NaN            NaN
# 1050226                    4.0                  NaN            NaN
#
# [1050227 rows x 45 columns]

# %% [markdown]
# ### 时序图像绘制

# %%
# 时序图像绘制
# 参数
division_label = 'S_INFO_COMPIND_NAME1' # 根据这个字段的类别画线
Filters = [
    ('BOND_TYPE','==','产业债'),
]
CrossSectionConfig = {
    'date':'20230821', # 截面日期   原本是20230921，但是数据都是0，所以改掉
    'plotCrossSection':True, # 是否绘制date时间的柱状截面图
}
# methods 0: 简单平均 1: 中位数 2: 剩余本金加权
BondAnalyzer.plotCreditSpread(
    data=df,
    filters=Filters,
    divisionLabel=division_label,
    methods=[1,2],
    config=CrossSectionConfig
)
# Out:
# 数据筛选中...请等待
# 筛选结果数据量： 100630

# %% [markdown]
# ### 个债预警

# %%
ALARMRES = BondAnalyzer.initBondAlarms(
    df,
    YIELD_CHANGE_PERIOD=YIELD_CHANGE_PERIOD, # 累计收益周期
    QUANTILE=QUANTILE, # 预警分位数
    ROLLING_WINDOW=ROLLING_WINDOW, # 历史分位窗口
    ALARM_PERIOD=ALARM_PERIOD, # 预警窗口
    config=alarmConfig
)
# Out:
# 开始检测最近20日出现超越7日累计估值收益变动的绝对值在历史250日内的0.98分位数的20230921债券
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14492\877561513.py in <module>
# ----> 1 ALARMRES = BondAnalyzer.initBondAlarms(
#       2     df,
#       3     YIELD_CHANGE_PERIOD=YIELD_CHANGE_PERIOD, # 累计收益周期
#       4     QUANTILE=QUANTILE, # 预警分位数
#       5     ROLLING_WINDOW=ROLLING_WINDOW, # 历史分位窗口
#
# E:\Jupyter notebook\债券分析\Bonder.py in initBondAlarms(self, data, YIELD_CHANGE_PERIOD, QUANTILE, ROLLING_WINDOW, ALARM_PERIOD, config)
#     121             'plot':False,
#     122         }
# --> 123         df_alarmed_pos_bond,df_alarmed_neg_bond = self.showSingleBond(
#     124             data=data,
#     125             bond_codes=bond_codes,
#
# E:\Jupyter notebook\债券分析\Bonder.py in showSingleBond(self, data, bond_codes, YIELD_CHANGE_PERIOD, QUANTILE, ROLLING_WINDOW, ALARM_PERIOD, TODAY, config)
#      57         pos_res = []
#      58         neg_res = []
# ---> 59         for bond_code in pbar(bond_codes):
#      60             single_bond = data.loc[bond_code]
#      61             single_bond = single_bond.loc[single_bond['TRADE_DT']<=TODAY]
#
# TypeError: 'module' object is not callable

# %%
# Mac 3500个债 约90s Windows较慢 4mins30s
# 债券累计存续时常小于250天不预警
YIELD_CHANGE_PERIOD=7
QUANTILE=0.98
ROLLING_WINDOW=250
ALARM_PERIOD=20
alarmConfig = {
    'TODAY':'20230921' #扫描哪天的存续债
}
ALARMRES = BondAnalyzer.initBondAlarms(
    df,
    YIELD_CHANGE_PERIOD=YIELD_CHANGE_PERIOD, # 累计收益周期
    QUANTILE=QUANTILE, # 预警分位数
    ROLLING_WINDOW=ROLLING_WINDOW, # 历史分位窗口
    ALARM_PERIOD=ALARM_PERIOD, # 预警窗口
    config=alarmConfig
)
df_alarmed_pos_bond = ALARMRES['df_alarmed_pos_bond']
df_alarmed_neg_bond = ALARMRES['df_alarmed_neg_bond']
alarmed_pos_bond_codes = ALARMRES['alarmed_pos_bond_codes']
alarmed_neg_bond_codes = ALARMRES['alarmed_neg_bond_codes']
ALARMED_POS_BONDS = ALARMRES['ALARMED_POS_BONDS']
ALARMED_NEG_BONDS = ALARMRES['ALARMED_NEG_BONDS']
# Out:
# 开始检测最近20日出现超越7日累计估值收益变动的绝对值在历史250日内的0.98分位数的20230921债券
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14492\3355283907.py in <module>
#       8     'TODAY':'20230921' #扫描哪天的存续债
#       9 }
# ---> 10 ALARMRES = BondAnalyzer.initBondAlarms(
#      11     df,
#      12     YIELD_CHANGE_PERIOD=YIELD_CHANGE_PERIOD, # 累计收益周期
#
# E:\Jupyter notebook\债券分析\Bonder.py in initBondAlarms(self, data, YIELD_CHANGE_PERIOD, QUANTILE, ROLLING_WINDOW, ALARM_PERIOD, config)
#     121             'plot':False,
#     122         }
# --> 123         df_alarmed_pos_bond,df_alarmed_neg_bond = self.showSingleBond(
#     124             data=data,
#     125             bond_codes=bond_codes,
#
# E:\Jupyter notebook\债券分析\Bonder.py in showSingleBond(self, data, bond_codes, YIELD_CHANGE_PERIOD, QUANTILE, ROLLING_WINDOW, ALARM_PERIOD, TODAY, config)
#      57         pos_res = []
#      58         neg_res = []
# ---> 59         for bond_code in pbar(bond_codes):
#      60             single_bond = data.loc[bond_code]
#      61             single_bond = single_bond.loc[single_bond['TRADE_DT']<=TODAY]
#
# TypeError: 'module' object is not callable

# %%
df_alarmed_pos_bond, df_alarmed_neg_bond # 最近突破日期在

# %%
SHOW_POS_BONDS = list(ALARMED_POS_BONDS.index.unique())[:1]
SHOW_NEG_BONDS = list(ALARMED_NEG_BONDS.index.unique())[:1]
config = {
    'plot':True,
    'plot_abs':False,
}
POS_SUMMARY,_= BondAnalyzer.showSingleBond(
    data=ALARMED_POS_BONDS, 
    bond_codes=SHOW_POS_BONDS,
    YIELD_CHANGE_PERIOD=YIELD_CHANGE_PERIOD, 
    QUANTILE=QUANTILE,
    ROLLING_WINDOW=ROLLING_WINDOW,
    ALARM_PERIOD=ALARM_PERIOD,
    TODAY = '20230921',
    config=config
)
_,NEG_SUMMARY = BondAnalyzer.showSingleBond(
    data=ALARMED_NEG_BONDS, 
    bond_codes=SHOW_NEG_BONDS,
    YIELD_CHANGE_PERIOD=YIELD_CHANGE_PERIOD,
    QUANTILE=QUANTILE,
    ROLLING_WINDOW=ROLLING_WINDOW,
    ALARM_PERIOD=ALARM_PERIOD,
    TODAY = '20230921',
    config=config
)

# %%
POS_SUMMARY

# %%
NEG_SUMMARY

# %% [markdown]
# ### 热力图

# %%
# 参数 根据哪个字段统计
category = 'S_INFO_COMPIND_NAME2'
# category = ['S_INFO_COMPIND_NAME2','S_INFO_COMPIND_NAME3'] # 数组形式表示字段组合热力图

# %%
heatMapConfig = {
    'alarmres':ALARMRES,
    'filters': [
        ('S_INFO_COMPIND_NAME1','==','工业') # 查看细分热力使用
    ],
}
HEATMAP = BondAnalyzer.getHeatMap(df,category,config=heatMapConfig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14492\1592812575.py in <module>
#       1 heatMapConfig = {
# ----> 2     'alarmres':ALARMRES,
#       3     'filters': [
#       4         ('S_INFO_COMPIND_NAME1','==','工业') # 查看细分热力使用
#       5     ],
#
# NameError: name 'ALARMRES' is not defined

# %%
HEATMAP['ALARM_PRESSION']

# %%
HEATMAP['ALARM_SUMMARY']
